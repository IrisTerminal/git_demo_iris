# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
final_df = pd.read_csv("ODF_Fire_Occurrence_Data_2000-2022.csv")
final_df.head()
# Out:
#    Serial FireCategory  FireYear Area          DistrictName     UnitName  \
# 0  102649         STAT      2015  EOA          Klamath-Lake      Klamath
# 1  131239         STAT      2022  EOA  Walker Range - WRFPA     Crescent
# 2   58256         STAT      2000  EOA        Central Oregon     John Day
# 3   59312         STAT      2000  EOA      Northeast Oregon    La Grande
# 4   61657         STAT      2001  SOA      Southwest Oregon  Grants Pass
#
#   FullFireNumber       FireName Size_class  EstTotalAcres  ...  \
# 0   15-981082-16       Bass 497          B           3.20  ...
# 1   22-991220-23       Hay Fire          A            NaN  ...
# 2   00-952011-01   Slick Ear #2          B           0.75  ...
# 3   00-971024-01        Woodley          C          80.00  ...
# 4   01-712133-02  QUEENS BRANCH          A           0.10  ...
#
#         Industrial_Restriction            Ign_DateTime  \
# 0  Does Not Apply - Eastern OR  09/02/2015 05:00:00 PM
# ...

# %%
final_df.loc[final_df["Serial"].idxmax(), "DistrictName"]
# Out:
# 'North Cascade'

# %%
final_df.describe()
# Out:
#               Serial     FireYear  EstTotalAcres  Protected_Acres  \
# count   23490.000000  23490.00000   23411.000000     23490.000000
# mean    90425.933461   2010.80132     270.802503        63.454008
# std     20901.016028      6.73508    6816.736966      1973.577812
# min     57485.000000   2000.00000       0.000000         0.000000
# 25%     72508.500000   2005.00000       0.010000         0.010000
# 50%     88340.000000   2011.00000       0.100000         0.100000
# 75%    107432.500000   2017.00000       0.500000         0.350000
# max    134021.000000   2022.00000  499945.000000    154570.000000
#
#              Lat_DD       Long_DD           Sec  DistrictCode      UnitCode
# count  23480.000000  23480.000000  23478.000000  23490.000000  23490.000000
# mean      43.718410   -122.258736     18.576753     77.754662    779.371052
# std        1.226385      1.707589     10.439507     14.618857    146.534574
# ...

# %%
sns.pairplot(data = final_df);
