# %% [markdown]
# ## Primer
#
# The goal of this project is to investigate any potential correlation between human activity and a potential rise in fires over the past decades, both from arson and environmental affects caused by human activities. Forests are incredibly important as carbon sinks and oxygen producers on earth, so their health is also our health.
#
# To tackle this issue, we will be incorporating data from the Oregon Fire Department as well as Kaggle, from US Census data, in order to put together a view of what fires have occurred in the past 20 to 25 years, and see if their rate has increased, as well as use data methods to determine how weather and human activity could have directly or indirectly affected their formation and time to be contained.

# %% [markdown]
# ## Modules
#
# The modules we will be importing are seaborn, matplotlib.pyplot, pandas, warnings, and numpy. We will need pandas to construct our DataFrame, and seaborn and matplotlib to plot and help navigate our data in more visual ways. numpy will also assist in these, and warnings will serve to show any potential errors in the code. operating system (os) will allow us to access the file, getting around some finicky issues with the notebook. importing regex will allow us to more accurately filter through string objects.

# %%
import seaborn as sns
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd
import os
import warnings

# %%
os.getcwd()
# Out:
# '/home/jovyan/data271_sp26/lab/lab08/final project folder'

# %%
os.listdir()
# Out:
# ['finalProj.ipynb',
#  '.ipynb_checkpoints',
#  'ODF_Fire_Occurrence_Data_2000-2022.csv']

# %%
final_df = pd.read_csv("ODF_Fire_Occurrence_Data_2000-2022.csv")
final_df.head()
# Out:
#    Serial FireCategory  FireYear Area   DistrictName       UnitName  \
# 0  108204         STAT      2017  EOA   Klamath-Lake       Lakeview
# 1   68272         STAT      2003  NOA  North Cascade        Santiam
# 2   75461         STAT      2006  EOA   Klamath-Lake        Klamath
# 3   98874         STAT      2014  NOA   Forest Grove  Columbia City
# 4  112552         STAT      2017  NOA  North Cascade        Santiam
#
#   FullFireNumber              FireName Size_class  EstTotalAcres  ...  \
# 0   17-982068-18            Castle 483          A            NaN  ...
# 1   03-582216-04  Marion Forks Move Up          A            0.0  ...
# 2   06-981055-07                  BUCK          A            0.1  ...
# 3   14-532076-15      Hafferman Rd. #1          A            0.1  ...
# 4   17-582069-18     Lyons Preposition          A            NaN  ...
#
#     Industrial_Restriction            Ign_DateTime          ReportDateTime  \
# ...

# %%
final_df.describe()
# Out:
#               Serial     FireYear  EstTotalAcres  Protected_Acres  \
# count   23490.000000  23490.00000   23411.000000     23490.000000
# mean    90425.933461   2010.80132     270.802503        63.454008
# std     20901.016028      6.73508    6816.736966      1973.577812
# min     57485.000000   2000.00000       0.000000         0.000000
# 25%     72508.500000   2005.00000       0.010000         0.010000
# 50%     88340.000000   2011.00000       0.100000         0.100000
# 75%    107432.500000   2017.00000       0.500000         0.350000
# max    134021.000000   2022.00000  499945.000000    154570.000000
#
#              Lat_DD       Long_DD           Sec  DistrictCode      UnitCode
# count  23480.000000  23480.000000  23478.000000  23490.000000  23490.000000
# mean      43.718410   -122.258736     18.576753     77.754662    779.371052
# std        1.226385      1.707589     10.439507     14.618857    146.534574
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Serial                  23490 non-null  int64
#  1   FireCategory            23490 non-null  object
#  2   FireYear                23490 non-null  int64
#  3   Area                    23490 non-null  object
#  4   DistrictName            23490 non-null  object
#  5   UnitName                23490 non-null  object
#  6   FullFireNumber          23490 non-null  object
#  7   FireName                23490 non-null  object
#  8   Size_class              23490 non-null  object
#  9   EstTotalAcres           23411 non-null  float64
#  10  Protected_Acres         23490 non-null  float64
#  11  HumanOrLightning        23490 non-null  object
#  12  CauseBy                 23362 non-null  object
#  13  GeneralCause            23490 non-null  object
# ...

# %%
final_df.shape
# Out:
# (23490, 38)

# %% [markdown]
# ## Data Source
#
# This data is sourced from the [Oregon Fire Department's survey of fires from 2000 to 2022.](https://data.oregon.gov/Natural-Resources/ODF-Fire-Occurrence-Data-2000-2022/fbwv-q84y/related_content)

# %% [markdown]
# Originally, it was simply gathered to determine causes of fire as well as point out the locations in which they occurred. Many of the data points pertain to cause, acres burned, protected acres burned, the date, as well as serial numbers, names of the fire and what units and districts related to them.
